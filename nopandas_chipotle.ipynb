# %%
import numpy as np
import csv
import re

# %%
input_file = ('/Users/minnawin/PythonWorkInProgress/orders.tsv')
opened_file = open(input_file, "rb")
df = csv.reader(opened_file, delimiter="\t")

# %%
data = []
header = df.next()

for row in df:
    #print row
    data.append(row)
num_cols = len(data[0])
print("number of columns: %s")%(num_cols)
num_rows = len(data)
print("number of rows: %s")%(num_rows)
# Out:
# number of columns: 5
# number of rows: 4622

# %%
#Calculate the total amount of sales from these two locations and time period
sum = 0
cost = []
for row in data:
    #convert the string representation of the item_price into a float
    #row[4] = row[4].str.replace('$','')
   # row[4] = row[4].astype(float)
    print("item price:%s")%(row[4])
   # cost = row[4]
#Convert the item_price into float, after you remove the '$'
#df['item_price'] = df['item_price'].str.replace('$','')
#df['item_price'] = df['item_price'].astype(float)

#print(df['item_price'])
# Out:
# item price:$2.39
# item price:$3.39
# item price:$3.39
# item price:$2.39
# item price:$16.98
# item price:$10.98
# item price:$1.69
# item price:$11.75
# item price:$9.25
# item price:$9.25
# item price:$4.45
# item price:$8.75
# item price:$8.75
# item price:$11.25
# item price:$4.45
# item price:$2.39
# item price:$8.49
# item price:$8.49
# item price:$2.18
# item price:$8.75
# item price:$4.45
# item price:$8.99
# item price:$3.39
# item price:$10.98
# item price:$3.39
# item price:$2.39
# item price:$8.49
# item price:$8.99
# item price:$1.09
# item price:$8.49
# item price:$2.39
# item price:$8.99
# item price:$1.69
# item price:$8.99
# item price:$1.09
# item price:$8.75
# item price:$8.75
# item price:$4.45
# item price:$2.95
# item price:$11.75
# item price:$2.15
# item price:$4.45
# item price:$11.25
# item price:$11.75
# item price:$8.75
# item price:$10.98
# item price:$8.99
# item price:$3.39
# item price:$8.99
# item price:$3.99
# item price:$8.99
# item price:$2.18
# ...
